# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('credit_risk_dataset.csv')

# %%
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# ...

# %%
df.dtypes
# Out:
# person_age                      int64
# person_income                   int64
# person_home_ownership          object
# person_emp_length             float64
# loan_intent                    object
# loan_grade                     object
# loan_amnt                       int64
# loan_int_rate                 float64
# loan_status                     int64
# loan_percent_income           float64
# cb_person_default_on_file      object
# cb_person_cred_hist_length      int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32581.000000   3.258100e+04       31686.000000  32581.000000
# mean      27.734600   6.607485e+04           4.789686   9589.371106
# std        6.348078   6.198312e+04           4.142630   6322.086646
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.920000e+04           7.000000  12200.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   29465.000000  32581.000000         32581.000000
# mean       11.011695      0.218164             0.170203
# std         3.240459      0.413006             0.106782
# min         5.420000      0.000000             0.000000
# 25%         7.900000      0.000000             0.090000
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                             person_age  person_income  person_emp_length  \
# person_age                    1.000000       0.173202           0.163106
# person_income                 0.173202       1.000000           0.134268
# person_emp_length             0.163106       0.134268           1.000000
# loan_amnt                     0.050787       0.266820           0.113082
# loan_int_rate                 0.012580       0.000792          -0.056405
# loan_status                  -0.021629      -0.144449          -0.082489
# loan_percent_income          -0.042411      -0.254471          -0.054111
# cb_person_cred_hist_length    0.859133       0.117987           0.144699
#
#                             loan_amnt  loan_int_rate  loan_status  \
# person_age                   0.050787       0.012580    -0.021629
# person_income                0.266820       0.000792    -0.144449
# person_emp_length            0.113082      -0.056405    -0.082489
# ...

# %%
# heatmap for correlation 
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap="coolwarm",
    fmt=".2f",
    linewidths=0.5)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# ...

# %%
# data preprocessing

# %%
df.isnull().sum()
# Out:
# person_age                       0
# person_income                    0
# person_home_ownership            0
# person_emp_length              895
# loan_intent                      0
# loan_grade                       0
# loan_amnt                        0
# loan_int_rate                 3116
# loan_status                      0
# loan_percent_income              0
# cb_person_default_on_file        0
# cb_person_cred_hist_length       0
# dtype: int64

# %%
df['person_emp_length']
# Out:
# 0        123.0
# 1          5.0
# 2          1.0
# 3          4.0
# 4          8.0
#          ...
# 32576      1.0
# 32577      4.0
# 32578      3.0
# 32579      5.0
# 32580      2.0
# Name: person_emp_length, Length: 32581, dtype: float64

# %%
sns.boxplot(df['person_emp_length'])
# Out:
# <Axes: ylabel='person_emp_length'>

# %%
sns.boxplot(df['person_age'])
# Out:
# <Axes: ylabel='person_age'>

# %%
# person_age is less than person_emp_length not possible

df[df['person_age']<=df['person_emp_length']]
# Out:
#      person_age  person_income person_home_ownership  person_emp_length  \
# 0            22          59000                  RENT              123.0
# 210          21         192000              MORTGAGE              123.0
#
#     loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0      PERSONAL          D      35000          16.02            1
# 210     VENTURE          A      20000           6.54            0
#
#      loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                   0.59                         Y                           3
# 210                 0.10                         N                           4

# %%
df[(df['person_age']-df['person_emp_length'])<10]
# Out:
#      person_age  person_income person_home_ownership  person_emp_length  \
# 0            22          59000                  RENT              123.0
# 210          21         192000              MORTGAGE              123.0
#
#     loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0      PERSONAL          D      35000          16.02            1
# 210     VENTURE          A      20000           6.54            0
#
#      loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                   0.59                         Y                           3
# 210                 0.10                         N                           4

# %%
df.shape
# Out:
# (32581, 12)

# %%
# person_age is greater than 100 thats not possible 
df[df['person_age']>=100]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 81            144         250000                  RENT                4.0
# 183           144         200000              MORTGAGE                4.0
# 575           123          80004                  RENT                2.0
# 747           123          78000                  RENT                7.0
# 32297         144        6000000              MORTGAGE               12.0
#
#       loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 81        VENTURE          C       4800          13.57            0
# 183     EDUCATION          B       6000          11.86            0
# 575     EDUCATION          B      20400          10.25            0
# 747       VENTURE          B      20000            NaN            0
# 32297    PERSONAL          C       5000          12.73            0
#
#        loan_percent_income cb_person_default_on_file  \
# 81                    0.02                         N
# ...

# %%
# now i am dropping the rows who's age is greater than 100
df =df[df['person_age'] <= 100]

# %%
df[df['person_age']>=100]
# Out:
# Empty DataFrame
# Columns: [person_age, person_income, person_home_ownership, person_emp_length, loan_intent, loan_grade, loan_amnt, loan_int_rate, loan_status, loan_percent_income, cb_person_default_on_file, cb_person_cred_hist_length]
# Index: []

# %%
df=df[df['person_age']>df['person_emp_length']]

# %%
df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# 5              21           9900                   OWN                2.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
df[(df['person_age']-df['person_emp_length'])<15]
# Out:
# Empty DataFrame
# Columns: [person_age, person_income, person_home_ownership, person_emp_length, loan_intent, loan_grade, loan_amnt, loan_int_rate, loan_status, loan_percent_income, cb_person_default_on_file, cb_person_cred_hist_length]
# Index: []

# %%
sns.boxplot(df['person_emp_length'])
# Out:
# <Axes: ylabel='person_emp_length'>

# %%
sns.boxplot(df['person_age'])
# Out:
# <Axes: ylabel='person_age'>

# %%
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
# 5          21           9900                   OWN                2.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
# 5     VENTURE          A       2500           7.14            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 1                 0.10                         N                           2
# ...

# %%
df.groupby('person_home_ownership')['person_income'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='person_home_ownership'>

# %%
df.groupby('loan_intent')['person_income'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='loan_intent'>

# %%
df.groupby('loan_grade')['loan_status'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='loan_grade'>

# %%
# feature encoding
#>> converting the srt to int

# %%
df.dtypes
# Out:
# person_age                      int64
# person_income                   int64
# person_home_ownership          object
# person_emp_length             float64
# loan_intent                    object
# loan_grade                     object
# loan_amnt                       int64
# loan_int_rate                 float64
# loan_status                     int64
# loan_percent_income           float64
# cb_person_default_on_file      object
# cb_person_cred_hist_length      int64
# dtype: object

# %%
df['person_home_ownership'].unique()
# Out:
# array(['OWN', 'MORTGAGE', 'RENT', 'OTHER'], dtype=object)

# %%
# person_home_ownership 
df['person_home_ownership']=df['person_home_ownership'].replace({'OWN':1,'MORTGAGE':2,'RENT':3,'OTHER':0})

# %%
df
# Out:
#        person_age  person_income  person_home_ownership  person_emp_length  \
# 1              21           9600                      1                5.0
# 2              25           9600                      2                1.0
# 3              23          65500                      3                4.0
# 4              24          54400                      3                8.0
# 5              21           9900                      1                2.0
# ...           ...            ...                    ...                ...
# 32576          57          53000                      2                1.0
# 32577          54         120000                      2                4.0
# 32578          65          76000                      3                3.0
# 32579          56         150000                      2                5.0
# 32580          66          42000                      3                2.0
#
# ...

# %%
df['loan_intent']=df['loan_intent'].replace({'EDUCATION':1,'MEDICAL':2,'VENTURE':3,'PERSONAL':4,'HOMEIMPROVEMENT':5,'DEBTCONSOLIDATION':6})

# %%
df.groupby('loan_intent')['loan_status'].sum()
# Out:
# loan_intent
# 1    1066
# 2    1565
# 3     814
# 4    1046
# 5     897
# 6    1437
# Name: loan_status, dtype: int64

# %%
df.head()
# Out:
#    person_age  person_income  person_home_ownership  person_emp_length  \
# 1          21           9600                      1                5.0
# 2          25           9600                      2                1.0
# 3          23          65500                      3                4.0
# 4          24          54400                      3                8.0
# 5          21           9900                      1                2.0
#
#    loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 1            1          B       1000          11.14            0
# 2            2          C       5500          12.87            1
# 3            2          C      35000          15.23            1
# 4            2          C      35000          14.27            1
# 5            3          A       2500           7.14            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# ...

# %%
df['loan_grade']=df['loan_grade'].replace({'A':1,'B':2,'C':3,'D':4,'E':5,'F':6,'G':7})

# %%
df.dtypes
# Out:
# person_age                      int64
# person_income                   int64
# person_home_ownership           int64
# person_emp_length             float64
# loan_intent                     int64
# loan_grade                      int64
# loan_amnt                       int64
# loan_int_rate                 float64
# loan_status                     int64
# loan_percent_income           float64
# cb_person_default_on_file      object
# cb_person_cred_hist_length      int64
# dtype: object

# %%
df['cb_person_default_on_file']=df['cb_person_default_on_file'].replace({'N':0,'Y':1})

# %%
df.head()
# Out:
#    person_age  person_income  person_home_ownership  person_emp_length  \
# 1          21           9600                      1                5.0
# 2          25           9600                      2                1.0
# 3          23          65500                      3                4.0
# 4          24          54400                      3                8.0
# 5          21           9900                      1                2.0
#
#    loan_intent  loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 1            1           2       1000          11.14            0
# 2            2           3       5500          12.87            1
# 3            2           3      35000          15.23            1
# 4            2           3      35000          14.27            1
# 5            3           1       2500           7.14            1
#
#    loan_percent_income  cb_person_default_on_file  cb_person_cred_hist_length
# ...

# %%
df.isnull().sum()
# Out:
# person_age                       0
# person_income                    0
# person_home_ownership            0
# person_emp_length                0
# loan_intent                      0
# loan_grade                       0
# loan_amnt                        0
# loan_int_rate                 3047
# loan_status                      0
# loan_percent_income              0
# cb_person_default_on_file        0
# cb_person_cred_hist_length       0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#    person_age  person_income  person_home_ownership  person_emp_length  \
# 1          21           9600                      1                5.0
# 2          25           9600                      2                1.0
# 3          23          65500                      3                4.0
# 4          24          54400                      3                8.0
# 5          21           9900                      1                2.0
#
#    loan_intent  loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 1            1           2       1000          11.14            0
# 2            2           3       5500          12.87            1
# 3            2           3      35000          15.23            1
# 4            2           3      35000          14.27            1
# 5            3           1       2500           7.14            1
#
#    loan_percent_income  cb_person_default_on_file  cb_person_cred_hist_length
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#    person_age  person_income  person_home_ownership  person_emp_length  \
# 1          21           9600                      1                5.0
# 2          25           9600                      2                1.0
# 3          23          65500                      3                4.0
# 4          24          54400                      3                8.0
# 5          21           9900                      1                2.0
#
#    loan_intent  loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 1            1           2       1000          11.14            0
# 2            2           3       5500          12.87            1
# 3            2           3      35000          15.23            1
# 4            2           3      35000          14.27            1
# 5            3           1       2500           7.14            1
#
#    loan_percent_income  cb_person_default_on_file  cb_person_cred_hist_length
# ...

# %%
df.shape
# Out:
# (28495, 12)

# %%
X = df.drop("loan_status", axis=1)
Y = df["loan_status"]

# %%
X
# Out:
#        person_age  person_income  person_home_ownership  person_emp_length  \
# 1              21           9600                      1                5.0
# 2              25           9600                      2                1.0
# 3              23          65500                      3                4.0
# 4              24          54400                      3                8.0
# 5              21           9900                      1                2.0
# ...           ...            ...                    ...                ...
# 32576          57          53000                      2                1.0
# 32577          54         120000                      2                4.0
# 32578          65          76000                      3                3.0
# 32579          56         150000                      2                5.0
# 32580          66          42000                      3                2.0
#
# ...

# %%
Y
# Out:
# 1        0
# 2        1
# 3        1
# 4        1
# 5        1
#         ..
# 32576    0
# 32577    0
# 32578    1
# 32579    0
# 32580    0
# Name: loan_status, Length: 28495, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=1,stratify=Y)

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model
# Out:
# DecisionTreeClassifier()

# %%
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree
tree.plot_tree(model)
plt.show()

# %%
Y_train_pred=model.predict(X_train)

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(Y_train,Y_train_pred)
acc
# Out:
# 1.0

# %%
# pre prunning
model_pre=DecisionTreeClassifier()

# %%
model_pre
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

param_grid = {
    "criterion": ["gini", "entropy", "log_loss"],
    "splitter": ["best"],
    "max_depth": [3, 4, 5, 6, 7, 8, 9],
    "min_samples_split": [2],
    "min_samples_leaf": [1, 2, 3, 4, 5]
}

model_pre_prun = GridSearchCV(
    DecisionTreeClassifier(random_state=1),
    param_grid,
    cv=5,
    scoring="f1",
    n_jobs=-1
)

model_pre_prun.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=1), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [3, 4, 5, 6, 7, 8, 9],
#                          'min_samples_leaf': [1, 2, 3, 4, 5],
#                          'min_samples_split': [2], 'splitter': ['best']},
#              scoring='f1')

# %%
accuracy_score(Y_train,model_pre_prun.predict(X_train))
# Out:
# 0.9349447271451132

# %%
# now we have avoided the overfitting

# %%
accuracy_score(Y_test,model_pre_prun.predict(X_test))
# Out:
# 0.927004737673276

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
    roc_auc_score,
    roc_curve,
    precision_recall_curve
)

# %%
y_pred_proba = model_pre_prun.predict_proba(X_test)[:, 1]
y_pred_proba
# Out:
# array([1.        , 0.01281085, 0.17467949, ..., 1.        , 0.12456747,
#        1.        ], shape=(5699,))

# %%
confusion_matrix(Y_test,model_pre_prun.predict(X_test))
# Out:
# array([[4409,   53],
#        [ 363,  874]])

# %%
accuracy_score(Y_test,model_pre_prun.predict(X_test))
# Out:
# 0.927004737673276

# %%
recall_score(Y_test,model_pre_prun.predict(X_test))
# Out:
# 0.7065481002425222

# %%
precision_score(Y_test,model_pre_prun.predict(X_test))
# Out:
# 0.9428263214670982

# %%
y_pred_custom = (y_pred_proba >= 0.2).astype(int)

# %%
y_pred_custom
# Out:
# array([1, 0, 0, ..., 1, 0, 1], shape=(5699,))

# %%
recall_score(Y_test,y_pred_custom)
# Out:
# 0.7396928051738076

# %%
precision_score(Y_test,y_pred_custom)
# Out:
# 0.8221024258760108

# %%
accuracy_score(Y_test,y_pred_custom)
# Out:
# 0.9087559220915951

# %%
import joblib

model_bundle = {
    "model": model_pre_prun,
    "threshold": 0.2
}

joblib.dump(model_bundle, "credit_risk_model.joblib")
# Out:
# ['credit_risk_model.joblib']
